# %% [markdown]
# # PART 1 - EV Charging Points

# %%
import osmnx as ox
import pandas as pd
import folium
from shapely.geometry import Point, Polygon, MultiPolygon

# %%
location = ox.geocode('Dublin, Ireland')

# %%
location
# Out:
# (53.3498006, -6.2602964)

# %%
# Download amenities data within a specified distance
distance = 20000  # Radius of 20 kilometers around the location
tags = {'amenity': True}
gdf = ox.geometries_from_point(location, tags=tags, dist=distance)

# %%
# Save the charging station data to a CSV file
gdf.to_csv('full_data.csv', index=False)

# %%
# Filter the data for charging stations
charging_stations = gdf[gdf['amenity'] == 'charging_station']

# %%
charging_stations = pd.DataFrame(charging_stations)

# Remove columns with no values
charging_stations = charging_stations.dropna(axis=1, how='all')

# Save the charging station data to a CSV file
charging_stations.to_csv('charging_stations_dublin.csv', index=False)

# %%
len(charging_stations)
# Out:
# 171

# %%
# Create a map centered around Dublin
latitude = location[0]  # Latitude of the center point
longitude = location[1] # Longitude of the center point
map_osm = folium.Map(location=[latitude, longitude], zoom_start=12)

# Add markers for each charging station location
for index, station in charging_stations.iterrows():
    name = station['name']
    geometry = station['geometry']

    # Extract latitude and longitude from the Polygon object
    if isinstance(geometry, Polygon):
        centroid = geometry.centroid
        lon = centroid.x
        lat = centroid.y
    else:
        point = Point(geometry)
        lon = point.x
        lat = point.y

    marker = folium.Marker(
        location=[lat, lon],
        popup=name
    )
    marker.add_to(map_osm)

# Display the map
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b801402469e0b9eec75a706376ca2b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b801402469e0b9eec75a706376ca2b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b801402469e0b9eec75a706376ca2b2 = L.map(
#                 &quot;map_5b801402469e0b9eec75a706376ca2b2&quot;,
#                 {
#                     center: [53.3498006, -6.2602964],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4629f9dc494467535b71edfe3b64ad2a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5b801402469e0b9eec75a706376ca2b2);
#
#
#             var marker_97e81dd5247dec231e97f589dafcedaf = L.marker(
#                 [53.3322769, -6.2555737],
#                 {}
#             ).addTo(map_5b801402469e0b9eec75a706376ca2b2);
#
#
#         var popup_f34b8d81d658bcb588291af78cd9041b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_262d960fd69b439835deda8ebd5d98e8 = $(`&lt;div id=&quot;html_262d960fd69b439835deda8ebd5d98e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ESB Electric Vehicle Charge Point&lt;/div&gt;`)[0];
#                 popup_f34b8d81d658bcb588291af78cd9041b.setContent(html_262d960fd69b439835deda8ebd5d98e8);
#
#
#
#         marker_97e81dd5247dec231e97f589dafcedaf.bindPopup(popup_f34b8d81d658bcb588291af78cd9041b)
#         ;
#
#
#
#
#             var marker_8a52f5a3ae9c87127a68644f0091ce9b = L.marker(
#                 [53.2834921, -6.1657318],
#                 {}
#             ).addTo(map_5b801402469e0b9eec75a706376ca2b2);
#
#
#         var popup_eb01888adcdd85cd795a86e5f28be10f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9589cac3579607df0bab852465fe6961 = $(`&lt;div id=&quot;html_9589cac3579607df0bab852465fe6961&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nissan Fast Charge Point&lt;/div&gt;`)[0];
#                 popup_eb01888adcdd85cd795a86e5f28be10f.setContent(html_9589cac3579607df0bab852465fe6961);
#
#
#
#         marker_8a52f5a3ae9c87127a68644f0091ce9b.bindPopup(popup_eb01888adcdd85cd795a86e5f28be10f)
#         ;
#
#
#
#
#             var marker_0319626bfcd742afe6a0740f9a530d45 = L.marker(
#                 [53.2943233, -6.37003],
#                 {}
#             ).addTo(map_5b801402469e0b9eec75a706376ca2b2);
#
#
#         var popup_c56bd34544fb5780856d05f179259ec6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4738607e9b9b2a1894dd906de1d9a172 = $(`&lt;div id=&quot;html_4738607e9b9b2a1894dd906de1d9a172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nissan Fast Charger&lt;/div&gt;`)[0];
#                 popup_c56bd34544fb5780856d05f179259ec6.setContent(html_4738607e9b9b2a1894dd906de1d9a172);
#
#
#
#         marker_0319626bfcd742afe6a0740f9a530d45.bindPopup(popup_c56bd34544fb5780856d05f179259ec6)
#         ;
#
#
#
#
#             var marker_64519150feb302c3cf41c23c726d9b9e = L.marker(
#                 [53.314832, -6.394243],
#                 {}
#             ).addTo(map_5b801402469e0b9eec75a706376ca2b2);
#
#
#         var popup_4a8b13d6a6ecc34fe12165e370d19f8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9fa47a0a4e94535a860cd28a754ecc18 = $(`&lt;div id=&quot;html_9fa47a0a4e94535a860cd28a754ecc18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ESB Electric Vehicle Fast Charge Point&lt;/div&gt;`)[0];
#                 popup_4a8b13d6a6ecc34fe12165e370d19f8e.setContent(html_9fa47a0a4e94535a860cd28a754ecc18);
#
#
#
#         marker_64519150feb302c3cf41c23c726d9b9e.bindPopup(popup_4a8b13d6a6ecc34fe12165e370d19f8e)
#         ;
#
#
#
#
#             var marker_df725e33fdd21e5f9fb3bb7bff7d3cb5 = L.marker(
#                 [53.3773496, -6.3919694],
#                 {}
#             ).addTo(map_5b801402469e0b9eec75a706376ca2b2);
#
#
#         var popup_6f3df4e39cbc2a77310b424bf6903954 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_73b243ea4ae087c224bb35418ec00811 = $(`&lt;div id=&quot;html_73b243ea4ae087c224bb35418ec00811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ESB Electric Vehicle Charge Point&lt;/div&gt;`)[0];
#                 popup_6f3df4e39cbc2a77310b424bf6903954.setContent(html_73b243ea4ae087c224bb35418ec00811);
#
#
#
#         marker_df725e33fdd21e5f9fb3bb7bff7d3cb5.bindPopup(popup_6f3df4e39cbc2a77310b424bf6903954)
#         ;
#
#
#
#
#             var marker_7198fd2eceb

# %% [markdown]
# # PART 2 - Hotspots

# %%
gdf['amenity'].unique()
# Out:
# array(['fuel', 'parking_entrance', 'library', 'theatre', 'parking',
#        'restaurant', 'telephone', 'recycling', 'post_office', 'post_box',
#        'atm', 'pub', 'vending_machine', 'post_depot', 'fast_food',
#        'pharmacy', 'police', 'nursing_home', 'waste_basket', 'toilets',
#        'bank', 'taxi', 'cinema', 'social_facility', 'place_of_worship',
#        'community_centre', 'bicycle_parking', 'fountain', 'nightclub',
#        'cafe', 'arts_centre', 'bar', 'drinking_water', 'events_venue',
#        'kindergarten', 'childcare', 'coast_guard', 'bench', 'veterinary',
#        'dentist', 'shelter', 'waste_disposal', 'clock', 'bicycle_rental',
#        'marketplace', 'college', 'car_wash', 'car_rental', 'studio',
#        'doctors', 'driving_school', 'box_office', 'school',
#        'internet_cafe', 'casino', 'ferry_terminal', 'ice_cream',
#        'research_institute', 'clinic', 'weighbridge', 'charging_station',
#        'ticket_validator', 'parking_space', 'internet_access', 'hospital',
#        'bbq', 'car_sharing', 'music_school', 'training',
#        'language_school', 'stripclub', 'courthouse', 'yes', 'university',
#        'parcel_locker', 'animal_boarding', 'funeral_hall', 'soft_play',
#        'conference_centre', 'photo_booth', 'compressed_air', 'grave_yard',
#        'loading_dock', 'smoking_area', 'bureau_de_change', 'monastery',
#        'public_bookcase', 'bicycle_repair_station', 'coworking_space',
#        'boat_rental', 'animal_shelter', 'trolley_bay', 'grit_bin',
#        'left_luggage', 'dojo', 'watering_place', 'table', 'food_court',
#        'money_transfer', 'vehicle_inspection', 'biergarten',
#        'hunting_stand', 'shower', 'payment_centre', 'animal_breeding',
#        'vacuum_cleaner', 'pastoral', 'dive_centre', 'ski_school',
#        'ski_rental', 'payment_terminal', 'water_point',
#        'motorcycle_parking', 'nameplate', 'reception_desk', 'piano',
#        'fixme', 'weighing_machine', 'sculpture', 'baking_oven',
#        'bus_station', 'gambling', 'townhall', 'exhibition_centre',
#        'scout_hut', 'fire_station', 'public', 'priory', 'bus_garage',
#        'boat_storage', 'court_yard', 'crematorium', 'yacht_club',
#        'prison', 'mortuary', 'dressing_room', 'private', 'clubhouse',
#        'presbytery', 'pavilion', 'pub;restaurant', 'first_aid',
#        'social_centre', 'waste_transfer_station', 'health_post',
#        'wheelwash', 'driver_training', 'stadium'], dtype=object)

# %%
hotspot_tags = ['fuel', 'parking', 'events_venue', 'college', 'hospital', 
            'university', 'food_court', 'exhibition_centre', 'townhall', 'stadium', 'conference_centre']

# %%
# Filter the data for the hotspots in the same 20 Km radius
hotspots = gdf[gdf['amenity'].isin(hotspot_tags)]

# %%
hotspots = pd.DataFrame(hotspots)

# Remove columns with no values
hotspots = hotspots.dropna(axis=1, how='all')

# Save the charging station data to a CSV file
hotspots.to_csv('hotspots.csv', index=False)

# %%
# Get the counts of each hotspot category
hotspots['amenity'].value_counts()
# Out:
# parking              6104
# fuel                  207
# college                88
# hospital               65
# university             43
# townhall                6
# events_venue            5
# food_court              5
# exhibition_centre       1
# stadium                 1
# Name: amenity, dtype: int64

# %%
# Get the counts of each hotspot category
gdf['amenity'].value_counts()
# Out:
# parking_space      6893
# parking            6104
# waste_basket       2026
# bench              1976
# bicycle_parking    1430
#                    ...
# scout_hut             1
# hunting_stand         1
# public                1
# priory                1
# stadium               1
# Name: amenity, Length: 148, dtype: int64

# %%
len(hotspots)
# Out:
# 6525

# %%
# # Create a map centered around Dublin
# latitude = location[0]  # Latitude of the center point
# longitude = location[1] # Longitude of the center point
# map_osm = folium.Map(location=[latitude, longitude], zoom_start=12)

# # Add markers for each charging station location
# for index, spot in hotspots.iterrows():
#     name = spot['name']
#     geometry = spot['geometry']

#     # Extract latitude and longitude from the Polygon object
#     if isinstance(geometry, Polygon):
#         centroid = geometry.centroid
#         lon = centroid.x
#         lat = centroid.y
#     elif isinstance(geometry, MultiPolygon):
#         centroid = geometry.centroid
#         lon = centroid.x
#         lat = centroid.y
#     else:
#         point = Point(geometry)
#         lon = point.x
#         lat = point.y

#     marker = folium.Marker(
#         location=[lat, lon],
#         popup=name
#     )
#     marker.add_to(map_osm)

# # Display the map
# map_osm
