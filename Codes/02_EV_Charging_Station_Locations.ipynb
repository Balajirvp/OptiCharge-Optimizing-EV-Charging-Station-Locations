# %%
import osmnx as ox
import requests
import pandas as pd
import folium

# %%
# Get the coordinates for Dublin, Ireland
location = ox.geocode('Dublin, Ireland')

# %%
location
# Out:
# (53.3498006, -6.2602964)

# %%
def get_charging_stations(latitude, longitude, radius, api_key):
    url = f"https://api.openchargemap.io/v3/poi/?output=json&latitude={latitude}&longitude={longitude}&distance={radius}&distanceunit=KM&maxresults=300&&verbose=false&key={api_key}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        return data

    except requests.exceptions.RequestException as e:
        print("Error occurred while retrieving charging station data:", e)
        return None
    except ValueError as e:
        print("Error occurred while parsing JSON response:", e)
        return None

# Dublin Center coordinates
latitude = location[0]
longitude = location[1]

# Radius in kilometers
radius = 25

# API key from OpenChargeMap
api_key = "431e2548-cd50-4959-971b-5e99539c2651"

charging_stations = get_charging_stations(latitude, longitude, radius, api_key)

if charging_stations:
    # Convert charging_stations to DataFrame
    df_charging_stations = pd.DataFrame(charging_stations)

    # Save DataFrame to CSV
    df_charging_stations.to_csv('02_charging_stations_initial.csv', index=False)

# %%
len(df_charging_stations)
# Out:
# 244

# %%
df_charging_stations.head()
# Out:
#                                         DataProvider  \
# 0  {'WebsiteURL': 'http://chargepoints.dft.gov.uk...
# 1  {'WebsiteURL': 'http://openchargemap.org', 'Da...
# 2  {'WebsiteURL': 'http://openchargemap.org', 'Da...
# 3  {'WebsiteURL': 'http://openchargemap.org', 'Da...
# 4  {'WebsiteURL': 'http://openchargemap.org', 'Da...
#
#                                         OperatorInfo  \
# 0  {'WebsiteURL': 'https://ebcharging.co.uk/', 'C...
# 1  {'WebsiteURL': 'https://www.gocharge.ie/charge...
# 2  {'WebsiteURL': 'http://www.teslamotors.com', '...
# 3  {'WebsiteURL': 'http://www.esb.ie/electric-car...
# 4  {'Comments': 'For use when the operator of the...
#
#                                            UsageType  \
# 0  {'IsPayAtLocation': True, 'IsMembershipRequire...
# 1  {'IsPayAtLocation': False, 'IsMembershipRequir...
# 2  {'IsPayAtLocation': False, 'IsMembershipRequir...
# 3  {'IsPayAtLocation': False, 'IsMembershipRequir...
# 4  {'IsPayAtLocation': False, 'IsMembershipRequir...
#
#                                     SubmissionStatus  IsRecentlyVerified  \
# 0  {'IsLive': True, 'ID': 100, 'Title': 'Imported...                True
# 1  {'IsLive': True, 'ID': 200, 'Title': 'Submissi...               False
# 2  {'IsLive': True, 'ID': 200, 'Title': 'Submissi...               False
# 3  {'IsLive': True, 'ID': 100, 'Title': 'Imported...               False
# 4  {'IsLive': True, 'ID': 100, 'Title': 'Imported...               False
#
#        DateLastVerified      ID                                  UUID  \
# 0  2023-05-04T08:52:00Z  214705  EE003D02-8575-420F-8797-C9B2D7D546C2
# 1  2020-08-08T15:24:00Z  127304  672CF633-6914-4CB9-9978-731411CF78B4
# 2  2018-10-11T13:54:00Z  109200  94158280-CA4C-4187-BF49-E860D5C73A9E
# 3  2021-12-29T16:32:00Z   66609  CAD14D5B-7DED-4534-A10A-650354BD9C09
# 4  2017-02-09T22:09:00Z   15102  B531CB42-F2C5-4C9A-99AD-94F6D02DEE89
#
#    DataProviderID            DataProvidersReference  ...  \
# 0              18  153a719109d5901f816d699f83ba381e  ...
# 1               1                               NaN  ...
# 2               1                               NaN  ...
# 3               1                               NaN  ...
# 4               1                               NaN  ...
#
#             DateCreated  SubmissionStatusTypeID  \
# 0  2023-02-09T08:13:00Z                     100
# 1  2019-06-03T08:42:00Z                     200
# 2  2018-10-11T13:54:00Z                     200
# 3  2016-05-23T16:08:00Z                     100
# 4  2012-12-11T15:08:00Z                     100
#
#                                           StatusType OperatorsReference  \
# 0                                                NaN                NaN
# 1  {'IsOperational': True, 'IsUserSelectable': Tr...              C8PJ7
# 2  {'IsOperational': True, 'IsUserSelectable': Tr...              44550
# 3  {'IsOperational': True, 'IsUserSelectable': Tr...              C6WKW
# 4  {'IsOperational': True, 'IsUserSelectable': Tr...  The Westin Dublin
#
#                            UsageCost NumberOfPoints  StatusTypeID  \
# 0                                NaN            NaN           NaN
# 1  €1 Connection Fee & €0.30 per kWh            2.0          50.0
# 2                                NaN            2.0          50.0
# 3                                NaN            2.0          50.0
# 4                                NaN            1.0          50.0
#
#                                      GeneralComments  UserComments MediaItems
# 0                                                NaN           NaN        NaN
# 1                                                NaN           NaN        NaN
# 2  2 Tesla Connectors, up to 6kW.Available by res...           NaN        NaN
# 3                                                NaN           NaN        NaN
# 4                                                NaN           NaN        NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Based on looking at the data, we saw that the columns 'AddressInfo' and 'Connections' contain the relevant information we need for our analysis. So we'll pick them and use them for further processing

# %%
df_1 = df_charging_stations.loc[:, ['UUID', 'AddressInfo']]
df_2 = df_charging_stations.loc[:, ['UUID', 'Connections']]

# %%
len(df_1)
# Out:
# 244

# %%
len(df_2)
# Out:
# 244

# %%
# Get the UUID value where 'Connections' column is empty
uuids_to_exclude = df_2.loc[df_2['Connections'].apply(lambda x: len(x) == 0), 'UUID'].values

# Remove the records in df_2 without any connection info
df_2 = df_2[df_2['Connections'].apply(lambda x: len(x) != 0)]

# Remove the corresponding records from df_1 as well
df_1 = df_1[~df_1['UUID'].isin(uuids_to_exclude)]

# %%
len(df_1)
# Out:
# 243

# %%
len(df_2)
# Out:
# 243

# %% [markdown]
# After analyzing the data, we saw that certain locations have multiple charging ports within the same spot. To handle this scenario, the 'Connections' column, which contains a dictionary data type with multiple keys representing each charging port, can be split into individual records. The next section does exactly that:

# %%
arr1 = []

for index, row in df_1.iterrows():
    # Access values of each column for the current row
    val1 = row['UUID']
    val2 = [row['AddressInfo']]
    
    for dictionary in val2:
        dictionary['UUID'] = val1
        arr1.append(dictionary)

arr1 = pd.DataFrame(arr1)

# %%
arr1.head()
# Out:
#        ID                                   Title  \
# 0  215085                    The Spire Car Park 1
# 1  127650  Q-Park The Spire Multi-Storey Car Park
# 2  109546                          Cassidys Hotel
# 3   66955                     Parnell Square West
# 4   15448                       The Westin Dublin
#
#                                        AddressLine1         Town  Postcode  \
# 0                     Marlborough Place, North City       Dublin  D01 W207
# 1                              Cathal Brugha Street     Dublin 1       NaN
# 2               Cavendish Rowupper O'connell Street  City Centre  D01 V3P6
# 3                               Parnell Square West     Dublin 1       NaN
# 4  The Westin Dublin, Westmoreland Street, Dublin 2       Dublin       NaN
#
#    CountryID                                            Country   Latitude  \
# 0          1  {'ISOCode': 'GB', 'ContinentCode': 'EU', 'ID':...  53.352036
# 1          3  {'ISOCode': 'IE', 'ContinentCode': 'EU', 'ID':...  53.352022
# 2          3  {'ISOCode': 'IE', 'ContinentCode': 'EU', 'ID':...  53.353102
# 3          3  {'ISOCode': 'IE', 'ContinentCode': 'EU', 'ID':...  53.353218
# 4          3  {'ISOCode': 'IE', 'ContinentCode': 'EU', 'ID':...  53.345479
#
#    Longitude                       AccessComments                 RelatedURL  \
# 0  -6.258841                                       https://ebcharging.co.uk/
# 1  -6.258432  Located on ground floor of car park     http://www.gocharge.ie
# 2  -6.261599                                  NaN                        NaN
# 3  -6.264812                                  NaN                        NaN
# 4  -6.258945                                  NaN                        NaN
#
#    Distance  DistanceUnit                                  UUID  \
# 0  0.266676             1  EE003D02-8575-420F-8797-C9B2D7D546C2
# 1  0.276272             1  672CF633-6914-4CB9-9978-731411CF78B4
# 2  0.377143             1  94158280-CA4C-4187-BF49-E860D5C73A9E
# 3  0.483969             1  CAD14D5B-7DED-4534-A10A-650354BD9C09
# 4  0.488841             1  B531CB42-F2C5-4C9A-99AD-94F6D02DEE89
#
#   StateOrProvince ContactTelephone1 AddressLine2 ContactTelephone2  \
# 0             NaN               NaN          NaN               NaN
# 1   County Dublin               NaN          NaN               NaN
# 2          Dublin  +353 1 87 80 555          NaN               NaN
# 3   County Dublin               NaN          NaN               NaN
# 4             NaN               NaN          NaN               NaN
#
#   ContactEmail
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
len(arr1)
# Out:
# 243

# %%
arr2 = []

for index, row in df_2.iterrows():
    # Access values of each column for the current row
    val1 = row['UUID']
    val2 = row['Connections']
    val3 = val2[0]['ConnectionType']
    
    for dictionary in val2:
        dictionary['UUID'] = val1
        dictionary['Name'] = val3['Title']
        arr2.append(dictionary)
        
arr2 = pd.DataFrame(arr2)

# %%
arr2.head()
# Out:
#        ID  ConnectionTypeID  \
# 0  357365                25
# 1  178256                25
# 2  154318                30
# 3   92032                25
# 4   91504                25
#
#                                       ConnectionType   Reference  \
# 0  {'FormalName': 'IEC 62196-2 Type 2', 'IsDiscon...  1837-01-01
# 1  {'FormalName': 'IEC 62196-2 Type 2', 'IsDiscon...         NaN
# 2  {'IsDiscontinued': False, 'IsObsolete': False,...         NaN
# 3  {'FormalName': 'IEC 62196-2 Type 2', 'IsDiscon...         NaN
# 4  {'FormalName': 'IEC 62196-2 Type 2', 'IsDiscon...         NaN
#
#    StatusTypeID                                         StatusType  LevelID  \
# 0            50  {'IsOperational': True, 'IsUserSelectable': Tr...      2.0
# 1            50  {'IsOperational': True, 'IsUserSelectable': Tr...      2.0
# 2            50  {'IsOperational': True, 'IsUserSelectable': Tr...      2.0
# 3            50  {'IsOperational': True, 'IsUserSelectable': Tr...      2.0
# 4            50  {'IsOperational': True, 'IsUserSelectable': Tr...      2.0
#
#                                                Level  Amps  Voltage  PowerKW  \
# 0  {'Comments': 'Over 2 kW, usually non-domestic ...  32.0    400.0     22.0
# 1  {'Comments': 'Over 2 kW, usually non-domestic ...  32.0    400.0     22.0
# 2  {'Comments': 'Over 2 kW, usually non-domestic ...   NaN      NaN      6.0
# 3  {'Comments': 'Over 2 kW, usually non-domestic ...  32.0    400.0     22.0
# 4  {'Comments': 'Over 2 kW, usually non-domestic ...  16.0    230.0      3.7
#
#    CurrentTypeID                                        CurrentType  \
# 0           20.0  {'Description': 'Alternating Current - Three P...
# 1           20.0  {'Description': 'Alternating Current - Three P...
# 2           10.0  {'Description': 'Alternating Current - Single ...
# 3           20.0  {'Description': 'Alternating Current - Three P...
# 4           10.0  {'Description': 'Alternating Current - Single ...
#
#                                    UUID                  Name  Quantity  \
# 0  EE003D02-8575-420F-8797-C9B2D7D546C2  Type 2 (Socket Only)       NaN
# 1  672CF633-6914-4CB9-9978-731411CF78B4  Type 2 (Socket Only)       2.0
# 2  94158280-CA4C-4187-BF49-E860D5C73A9E     Tesla (Model S/X)       2.0
# 3  CAD14D5B-7DED-4534-A10A-650354BD9C09  Type 2 (Socket Only)       2.0
# 4  B531CB42-F2C5-4C9A-99AD-94F6D02DEE89  Type 2 (Socket Only)       1.0
#
#   Comments
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
len(arr2)
# Out:
# 334

# %%
merged_df = arr1.merge(arr2, on='UUID', how='left')

# %%
len(merged_df)
# Out:
# 334

# %%
merged_df.to_csv('02_charging_stations_final.csv', index=False)

# %%
merged_df['Name'].unique()
# Out:
# array(['Type 2 (Socket Only)', 'Tesla (Model S/X)', 'CCS (Type 2)',
#        'CHAdeMO', 'Type 1 (J1772)', 'BS1363 3 Pin 13 Amp',
#        'NACS / Tesla Supercharger'], dtype=object)

# %%
# Define a dictionary to map colors to categories
color_map = {
    'Type 1 (J1772)': 'orange',
    'Type 2 (Socket Only)': 'blue',
    'CCS (Type 2)': 'red',
    'Tesla (Model S/X)': 'green',
    'CHAdeMO': 'gray',
    'BS1363 3 Pin 13 Amp': 'purple',
    'Tesla Supercharger': 'darkgreen'
}

# Create a map centered around Dublin to display the EV charging points
map_osm = folium.Map(location=[latitude, longitude], zoom_start=12)

# Add markers for each charging station location with a different marker color for different charge type
for index, row in merged_df.iterrows():
    name = row['Name'] + ', ' + row['Title'] + ', ' + row['AddressLine1'] + ', ' + str(row['Town'])
    lon = row['Longitude']
    lat = row['Latitude']
    
    category = row['Name']
    marker_color = color_map.get(category, 'gray')  # Use 'gray' if category not found in the color map

    # marker = folium.Marker(location=[lat, lon], popup=name)
    # marker = folium.CircleMarker(location=[lat, lon], radius=5, color=marker_color, fill=True, fill_color=marker_color, fill_opacity=1, popup=name)
    icon = folium.Icon(color=marker_color, icon='map-marker')  # Use the 'map-marker' icon with the specified color

    marker = folium.Marker(location=[lat, lon], icon=icon, popup=name)

    marker.add_to(map_osm)

# Display the map
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_296aeae97ed46ad7a2b757f58aae0c47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_296aeae97ed46ad7a2b757f58aae0c47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_296aeae97ed46ad7a2b757f58aae0c47 = L.map(
#                 &quot;map_296aeae97ed46ad7a2b757f58aae0c47&quot;,
#                 {
#                     center: [53.3498006, -6.2602964],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f102ceaa5ac6b337b872a45eba2524a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_296aeae97ed46ad7a2b757f58aae0c47);
#
#
#             var marker_ff6d7206fd014936d7d259403c492cae = L.marker(
#                 [53.352036, -6.258841],
#                 {}
#             ).addTo(map_296aeae97ed46ad7a2b757f58aae0c47);
#
#
#             var icon_cb010337995ff7a4ca0cd01bf9696169 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ff6d7206fd014936d7d259403c492cae.setIcon(icon_cb010337995ff7a4ca0cd01bf9696169);
#
#
#         var popup_dfc23d91869ffee5d342ea4a0bbb1bb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f541f9558ec5b4e8c1dd31e1d109afb7 = $(`&lt;div id=&quot;html_f541f9558ec5b4e8c1dd31e1d109afb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Type 2 (Socket Only), The Spire Car Park 1, Marlborough Place, North City, Dublin&lt;/div&gt;`)[0];
#                 popup_dfc23d91869ffee5d342ea4a0bbb1bb3.setContent(html_f541f9558ec5b4e8c1dd31e1d109afb7);
#
#
#
#         marker_ff6d7206fd014936d7d259403c492cae.bindPopup(popup_dfc23d91869ffee5d342ea4a0bbb1bb3)
#         ;
#
#
#
#
#             var marker_4ba56c68c9d800e4d76630c3fc33c8d5 = L.marker(
#                 [53.352022, -6.258432],
#                 {}
#             ).addTo(map_296aeae97ed46ad7a2b757f58aae0c47);
#
#
#             var icon_5b01b4bb6ade16a54246b7add9e01332 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ba56c68c9d800e4d76630c3fc33c8d5.setIcon(icon_5b01b4bb6ade16a54246b7add9e01332);
#
#
#         var popup_f99bdf7213ec26acacc73d6eea2d8f21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d13bc3b8fd905e6b8c9b8100f5cd195d = $(`&lt;div id=&quot;html_d13bc3b8fd905e6b8c9b8100f5cd195d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Type 2 (Socket Only), Q-Park The Spire Multi-Storey Car Park, Cathal Brugha Street, Dublin 1&lt;/div&gt;`)[0];
#                 popup_f99bdf7213ec26acacc73d6eea2d8f21.setContent(html_d13bc3b8fd905e6b8c9b8100f5cd195d);
#
#
#
#         marker_4ba56c68c9d800e4d76630c3fc33c8d5.bindPopup(popup_f99bdf7213ec26acacc73d6eea2d8f21)
#         ;
#
#
#
#
#             var marker_55e2244061bda1eec6b57037b4ed7252 = L.marker(
#                 [53.353102, -6.261599],
#                 {}
#             ).addTo(map_296aeae97ed46ad7a2b757f58aae0c47);
#
#
#             var icon_ccbb162de6cf3683e174b399adfa158a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_55e2244061bda1eec6b57037b4ed7252.setIcon(icon_ccbb162de6cf3683e174b399adfa158a);
#
#
#         var popup_95d0aaef7cadaf774d2c3f9ae8bec620 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10964b79d5369559bbe4a7f9ab011e76 = $(`&lt;div id=&quot;html_10964b79d5369559bbe4a7f9ab011e76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tesla (Model S/X), Cassidys Hotel, Cavendish Rowupper O&#x27;connell Street, City Centre&lt;/div&gt;`)[0];
#                 popup_95d0aaef7cadaf774d2c3f9ae8bec620.setContent(html_10964b79d5369559bbe4a7f9ab011e76);
#
#
#
#         marker_55e2244061bda1eec6b57037b4ed7252.bindPopup(popup_95d0aaef7cadaf774d2c3f9ae8bec620)
#         ;
#
#
#
#
#             var marker_170c96cf52dc327153df6be09b9a999b = L.marker(
#                 [53.353218, -6.264812],
#                 {}
#             ).addT
